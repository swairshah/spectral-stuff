# %%
from weight_solver import *
from laplacian import *
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
G = nx.complete_graph(10)
pos = nx.fruchterman_reingold_layout(G)
E = IncidenceMatrix(G)
Draw(G, pos = pos)

# %%
F = E.copy()
F, w = iterative_column_removal(E, F, 10)
H = GraphFromIncidenceMatrix(F, w)

# %%
weights = [H[u][v]['weight'] for u,v in H.edges()]

# %%
weights
# Out:
# [2.885973763874873,
#  2.1089808274470214,
#  2.896064581231081,
#  3.4207870837537833,
#  3.4207870837537842,
#  3.451059535822405,
#  2.8859737638748815,
#  3.4510595358223988,
#  3.3097880928355181,
#  3.3097880928355163]

# %%
nx.draw(G, node_color='orange', alpha = 0.6, node_size=100, edges = G.edges(), pos = pos)

# %%
nx.draw(H, node_color='orange', alpha = 0.6, node_size=100, edges = H.edges(), pos = pos, width = weights)
